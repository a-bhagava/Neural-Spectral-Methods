# %% [markdown]
# # Comparing Wavelet-Integrated NOs with NSM

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. CurledWake PDE: NSM vs Wavelet-NSM

# %%
abs_curled_wake_nsm = None 
abs_curled_wake_wav = None 
curled_wake_original = None

# %% [markdown]
# ### 2. Navier Stokes (0.8 Length Scale, re4): NSM vs Wavelet-NSM

# %%
abs_nav_stokes_8000_nsm = np.load('/mnt/home/abhagava/Neural-Spectral-Methods/log/ns.T3/re4:NSM./metric.erra.npy')
abs_nav_stokes_8000_wav = None 
pderes_nav_stokes_8000_nsm = np.load('/mnt/home/abhagava/Neural-Spectral-Methods/log/ns.T3/re4:NSM./metric.residual.npy')
pderes_nav_stokes_8000_wav = None

nav_stokes_8000_true = None 
nav_stokes_8000_pred_nsm = np.load('/mnt/home/abhagava/Neural-Spectral-Methods/log/ns.T3/re4:NSM./uhat.npy')
nav_stokes_8000_pred_wav = None

# %%
plt.plot(abs_nav_stokes_8000_nsm)
plt.title(r'NSM Model, ($\nu = 10^{-4}$), Abs Error on Test Set')
plt.ylabel('Absolute Error on Test Set')
plt.xlabel('Training Time (seconds)')
plt.yscale('log')

plt.grid()
plt.show()

# %%
plt.plot(pderes_nav_stokes_8000_nsm)
plt.title(r'NSM Model, ($\nu = 10^{-4}$), PDE Residual on Test Set')
plt.ylabel('PDE Residual on Test Set')
plt.xlabel('Training Time (seconds)')
plt.yscale('log')
plt.xscale('log')
yticks = [0.03, 0.04, 0.06, 0.08, 0.1]
plt.yticks(yticks, [f"{t:.2f}" for t in yticks])

plt.grid()
plt.show()

# %% [markdown]
# ### 3. Navier-Stokes (0.4 Length Scale, re4): NSM vs Wavelet-NSM

# %%
nav_stokes_4000_nsm = None 
nav_stokes_4000_wav = None 
nav_stokes_4000_original = None
